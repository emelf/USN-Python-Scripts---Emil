# %%
import numpy as np
import tensorflow as tf 
import graphviz
import pydot

from scipy.integrate import solve_ivp
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

#import os
#os.environ["PATH"] += os.pathsep + 'C:\Anaconda3\Library\bin\graphviz'

from tensorflow import keras
from tensorflow.keras.layers import Dense, Lambda, Concatenate

# %%
N_h1 = 40
N_h2 = 80

N_vars = 2
N_seq = 11
N_out = 2

#Functional API model 
inputs = keras.Input(shape=(N_vars, N_seq,), name="NN_Inputs")

#Split input variables such that there is N_vars small networks with input size N_seq 
# x1 = Lambda(lambda x: (tf.slice(x, (0, 0, 0), (1, 1, N_seq))), name="Variable_1")(inputs) 
# x2 = Lambda(lambda x: (tf.slice(x, (0, 1, 0), (1, 1, N_seq))), name="Variable_2")(inputs) 
# x3 = Lambda(lambda x: (tf.slice(x, (0, 2, 0), (1, 1, N_seq))), name="Variable_3")(inputs) 
x1, x2 = Lambda(lambda x: tf.split(x, num_or_size_splits=N_vars, axis=1))(inputs)

#Each mini-network will have one hidden layer. 
x1 = Dense(N_h1, activation='relu', name="Hidden_Layer_1_var1")(x1)
x2 = Dense(N_h1, activation='relu', name="Hidden_Layer_1_var2")(x2)
# x3 = Dense(N_h1, activation='relu', name="Hidden_Layer_1_var3")(x3)

#Merge the layers with Concatinate 
x_m = Concatenate(axis=-1, name="Merge_Layers")([x1, x2])

#One last hidden layer (or more layers)
x_m = Dense(N_h2, activation='relu', name="Main_Hidden_Layer_1")(x_m)

#Output: 
NN_out = Dense(N_out, name="NN_Output_Layer")(x_m)

model = keras.Model(inputs=inputs, outputs=NN_out, name="Param_est_NN")
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
              loss='mse', metrics=['accuracy'])

model.summary()
# Out:
# Model: "Param_est_NN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# NN_Inputs (InputLayer)          [(None, 2, 11)]      0
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              [(None, 1, 11), (Non 0           NN_Inputs[0][0]
# __________________________________________________________________________________________________
# Hidden_Layer_1_var1 (Dense)     (None, 1, 40)        480         lambda_23[0][0]
# __________________________________________________________________________________________________
# Hidden_Layer_1_var2 (Dense)     (None, 1, 40)        480         lambda_23[0][1]
# __________________________________________________________________________________________________
# Merge_Layers (Concatenate)      (None, 1, 80)        0           Hidden_Layer_1_var1[0][0]
#                                                                  Hidden_Layer_1_var2[0][0]
# __________________________________________________________________________________________________
# Main_Hidden_Layer_1 (Dense)     (None, 1, 80)        6480        Merge_Layers[0][0]
# __________________________________________________________________________________________________
# NN_Output_Layer (Dense)         (None, 1, 2)         162         Main_Hidden_Layer_1[0][0]
# ==================================================================================================
# Total params: 7,602
# Trainable params: 7,602
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, to_file='model.png')

# %%
#x = [V_c], u = [V_in], theta = [R, C]

class diff_model: 
    def __init__(self):
        self.u_range = (0, 10)
        self.x0_range = [(0, 10)]
        self.theta_range = [(1, 5), (0.1, 0.2)]
        self.t0 = 0
        self.t1 = 1
        self.N_steps = 200 
        self.t = np.linspace(self.t0, self.t1, self.N_steps+1)
        self.t_disc = lambda t: (np.abs(self.t - t)).argmin()
    
    def reset(self): 
        self.u = self.generate_inputs()
        self.th = np.array([np.random.uniform(th[0], th[1]) for th in self.theta_range])
        self.x0 = np.array([np.random.uniform(x0[0], x0[1]) for x0 in self.x0_range])
        
    def model(self, t, x): 
        u = self.u[self.t_disc(t)]
        return (u - x)/self.th[1]/self.th[0]
    
    def generate_inputs(self, change=0.01): 
        u = [] 
        for i in range(len(self.t)):
            if i == 0: 
                u_el = np.random.uniform(self.u_range[0], self.u_range[1])
            if np.random.rand() < change:
                u_el = np.random.uniform(self.u_range[0], self.u_range[1])
            u.append(u_el)            
        return u
    
    def solve_model(self, N_el):
        dN = self.N_steps//N_el
        self.reset()
        sol = solve_ivp(self.model, (0, 1), self.x0, t_eval=self.t[::dN])
        t_sol = []
        for t in sol.t:
            t_sol.append(ode_model.t_disc(t)) 
        u_sol = np.take(self.u, t_sol)
        x_sol = sol.y[0]
        
        return x_sol, u_sol, self.th, sol
    
    def solve_N_model(self, N_sim, N_el): 
        X_NN = []
        y_NN = []
        for i in range(N_sim): 
            x_sol, u_sol, th, _ = self.solve_model(N_el)
            X_NN.append([x_sol, u_sol])
            y_NN.append(th)
            
        X_NN = np.array(X_NN)
        y_NN = np.array(y_NN)
        X_scaler = MinMaxScaler() 
        y_scaler = MinMaxScaler() 
        self.X_scalers = []
        for i in range(len(X_NN[0])):
            self.X_scalers.append(X_scaler.fit(X_NN[:, i, :].reshape(-1, 1)))
        self.y_scaler = y_scaler.fit(y_NN)
        
        X_NN_scaled = [] 
        for X in X_NN: 
            X_el = []
            for X_var, X_scale in zip(X, self.X_scalers): 
                X_el.append(X_scale.transform([X_var])[0])
            X_NN_scaled.append(X_el)
        X_NN_scaled = np.array(X_NN_scaled)
        y_NN_scaled = self.y_scaler.transform(y_NN)
        
        return X_NN, y_NN, X_NN_scaled, y_NN_scaled
    
    def scale_data(self): 
        pass

# %%
ode_model = diff_model()
X_NN, y_NN, X_NN_sc, y_NN_sc = ode_model.solve_N_model(N_sim=2000, N_el=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_NN_sc, y_NN_sc, test_size=0.1)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=1, 
                       callbacks=[tf.keras.callbacks.EarlyStopping(patience=10)])
# Out:
# Epoch 1/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0921 - accuracy: 8.3333e-04 - val_loss: 0.0791 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0767 - accuracy: 0.0000e+00 - val_loss: 0.0712 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0684 - accuracy: 2.7778e-04 - val_loss: 0.0643 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 1800/1800 [==============================] - 5s 3ms/step - loss: 0.0650 - accuracy: 0.0000e+00 - val_loss: 0.0618 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0623 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0605 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0606 - accuracy: 2.7778e-04 - val_loss: 0.0634 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0587 - accuracy: 2.7778e-04 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 1800/1800 [==============================] - 3s 1ms/step - loss: 0.0583 - accuracy: 2.7778e-04 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 1800/1800 [==============================] - 3s 1ms/step - loss: 0.0578 - accuracy: 0.0000e+00 - val_loss: 0.0556 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0564 - accuracy: 0.0000e+00 - val_loss: 0.0536 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 1800/1800 [==============================] - 3s 1ms/step - loss: 0.0559 - accuracy: 2.7778e-04 - val_loss: 0.0533 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0556 - accuracy: 2.7778e-04 - val_loss: 0.0539 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0556 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0544 - accuracy: 2.7778e-04 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0539 - accuracy: 2.7778e-04 - val_loss: 0.0529 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0538 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0541 - accuracy: 0.0000e+00 - val_loss: 0.0560 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0531 - accuracy: 2.7778e-04 - val_loss: 0.0543 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0527 - accuracy: 5.5556e-04 - val_loss: 0.0554 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0516 - accuracy: 0.0000e+00 - val_loss: 0.0554 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0524 - accuracy: 5.5556e-04 - val_loss: 0.0561 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0515 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0506 - accuracy: 0.0000e+00 - val_loss: 0.0534 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0507 - accuracy: 5.5556e-04 - val_loss: 0.0539 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0502 - accuracy: 2.7778e-04 - val_loss: 0.0515 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0501 - accuracy: 2.7778e-04 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0499 - accuracy: 2.7778e-04 - val_loss: 0.0555 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0488 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0490 - accuracy: 5.5556e-04 - val_loss: 0.0625 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 1800/1800 [==============================] - 4s 2ms/step - loss: 0.0485 - accuracy: 5.5556e-04 - val_loss: 0.0558 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0484 - accuracy: 2.7778e-04 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0481 - accuracy: 2.7778e-04 - val_loss: 0.0616 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0475 - accuracy: 5.5556e-04 - val_loss: 0.0552 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 1800/1800 [==============================] - 3s 2ms/step - loss: 0.0478 - accuracy: 2.7778e-04 - val_loss: 0.0560 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 1800/1800 [==============================] - 3s 1ms/step - loss: 0.0469 - accuracy: 2.7778e-04 - val_loss: 0.0545 - val_accuracy: 0.0000e+00

# %%
hist = history.history 
fig, axes = plt.subplots(len(hist), 1)
for el, ax in zip(hist, axes): 
    ax.plot(hist[el])
    ax.set_title(el)
    
fig.set_figheight(6)
fig.set_figwidth(10)
fig.tight_layout(h_pad=-0.2)
plt.show()

# %%
# Split `x` into 3 tensors along dimension 1
s0, s1, s2 = tf.split(x, num_or_size_splits=3, axis=1)

# %%
s0.shape
# Out:
# TensorShape([5, 10, 10])

# %%
y_train
# Out:
# array([[0.11646138, 0.        ],
#        [0.48207161, 0.172061  ],
#        [0.        , 0.72218229],
#        [0.80623921, 0.73350377],
#        [0.19108696, 1.        ],
#        [0.27640652, 0.77998754],
#        [1.        , 0.47997818],
#        [0.59234373, 0.11161972],
#        [0.29969042, 0.69232029]])
